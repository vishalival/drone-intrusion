# %%
# Necessary impports and pip installs
# !pip3 install googlesearch-python
import pandas as pd
import os
import numpy as np
import re
from googlesearch import search
import requests
from bs4 import BeautifulSoup
import zipfile
import time
# Out:
# Requirement already satisfied: googlesearch-python in /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages (1.2.5)
# Requirement already satisfied: beautifulsoup4>=4.9 in /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages (from googlesearch-python) (4.12.3)
# Requirement already satisfied: requests>=2.20 in /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages (from googlesearch-python) (2.32.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages (from requests>=2.20->googlesearch-python) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages (from requests>=2.20->googlesearch-python) (2024.7.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages (from requests>=2.20->googlesearch-python) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages (from requests>=2.20->googlesearch-python) (1.26.19)

# %%
'''
Dataframe loading. The initial dataframes are zipped
big_drone_df : large raw FAA drone intrusion info.
airport_codes_2 : huge dataset with info on airport codes, latitude & longitude
'''

zip_file_path_drone = 'combined_UAS_sightings.csv.zip'
csv_file_name_drone = 'combined_UAS_sightings.csv'  

with zipfile.ZipFile(zip_file_path_drone) as z:
    with z.open(csv_file_name_drone) as f:
        big_drone_df = pd.read_csv(f)

zip_file_path_airport = "all-airport-data.xlsx.zip"
xlsx_file_name_airport = "all-airport-data.xlsx"

with zipfile.ZipFile(zip_file_path_airport) as z:
    with z.open(xlsx_file_name_airport) as f:
        airport_codes_2 = pd.read_excel(f)
# Out:
# /Users/vishalivallioor/anaconda3/lib/python3.10/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
big_drone_df
# Out:
#                       Date         State             City  \
# 0                 4/1/2022  PENNSYLVANIA       PITTSBURGH
# 1                 4/1/2022       FLORIDA            MIAMI
# 2                 4/1/2022    WASHINGTON          SEATTLE
# 3                 4/1/2022       ALABAMA           MOBILE
# 4                 4/1/2022    WASHINGTON          SEATTLE
# ...                    ...           ...              ...
# 18217  2019-12-31 00:00:00       FLORIDA  WEST PALM BEACH
# 18218  2019-12-31 00:00:00       FLORIDA       FORT MYERS
# 18219  2019-12-31 00:00:00       FLORIDA           NAPLES
# 18220  2019-12-31 00:00:00        HAWAII         HONOLULU
# 18221  2019-12-31 00:00:00       FLORIDA          ORLANDO
#
#                                                  Summary  \
# 0      PRELIM INFO FROM FAA OPS: PITTSBURGH, PA/UAS I...
# 1      PRELIM INFO FROM FAA OPS: MIAMI, FL/UAS INCIDE...
# 2      PRELIM INFO FROM FAA OPS: SEATTLE, WA/UAS INCI...
# 3      PRELIM INFO FROM FAA OPS: MOBILE, AL/UAS INCID...
# 4      PRELIM INFO FROM FAA OPS: SEATTLE, WA/UAS INCI...
# ...                                                  ...
# 18217  PRELIM INFO FROM FAA OPS: WEST PALM BEACH, FL/...
# 18218  PRELIM INFO FROM FAA OPS: FORT MYERS, FL/UAS I...
# 18219  _x000D_\nSummary: A/C WAS SOUTHBOUND TO APF AT...
# 18220  PRELIM INFO FROM FAA OPS: HONOLULU, HI/UAS INC...
# 18221  PRELIM INFO FROM FAA OPS: ORLANDO, FL/UAS INCI...
#
#                                        Source File
# 0      Reported-UAS-Sightings-April-June-2022.xlsx
# 1      Reported-UAS-Sightings-April-June-2022.xlsx
# 2      Reported-UAS-Sightings-April-June-2022.xlsx
# 3      Reported-UAS-Sightings-April-June-2022.xlsx
# 4      Reported-UAS-Sightings-April-June-2022.xlsx
# ...                                            ...
# 18217                 FY2020_Q1_UAS_Sightings.xlsx
# 18218                 FY2020_Q1_UAS_Sightings.xlsx
# 18219                 FY2020_Q1_UAS_Sightings.xlsx
# 18220                 FY2020_Q1_UAS_Sightings.xlsx
# 18221                 FY2020_Q1_UAS_Sightings.xlsx
#
# [18222 rows x 5 columns]

# %%
big_drone_df = big_drone_df[~big_drone_df['Summary'].str.startswith('_x000D', na=False)]

# Reset index if needed (optional)
big_drone_df.reset_index(drop=True, inplace=True)
big_drone_df = big_drone_df.dropna(subset=['Summary'])

# %%
''''
Line of code to extract all the 3 letter airport codes. 
'''

list_codes = list(airport_codes_2["Loc Id"])

big_drone_df['code'] = None

for index_2, row in big_drone_df.iterrows():
  x = row["Summary"]
  splitted_x = x.split()
  punc = '''!()-[]{};:'"\,<>.,/?@#$%^&*_~'''

  # Removing punctuations in string
  # Using loop + punctuation string
  index = 0
  for word in splitted_x:
      for letter in word:
        if letter in punc:
          word = word.replace(letter, "")
          splitted_x[index] = word
      index = index + 1
  filtered_codes = list(set([i for i in splitted_x if len(i) == 3 and i not in ["FAA", "UAS", "OPS", "THE"]]))
  for i in filtered_codes:
    if i in list_codes:
       big_drone_df.at[index_2, 'code'] = i

big_drone_df
# Out:
#                       Date         State             City  \
# 0                 4/1/2022  PENNSYLVANIA       PITTSBURGH
# 1                 4/1/2022       FLORIDA            MIAMI
# 2                 4/1/2022    WASHINGTON          SEATTLE
# 3                 4/1/2022       ALABAMA           MOBILE
# 4                 4/1/2022    WASHINGTON          SEATTLE
# ...                    ...           ...              ...
# 17889  2019-12-31 00:00:00       FLORIDA            MIAMI
# 17890  2019-12-31 00:00:00       FLORIDA  WEST PALM BEACH
# 17891  2019-12-31 00:00:00       FLORIDA       FORT MYERS
# 17892  2019-12-31 00:00:00        HAWAII         HONOLULU
# 17893  2019-12-31 00:00:00       FLORIDA          ORLANDO
#
#                                                  Summary  \
# 0      PRELIM INFO FROM FAA OPS: PITTSBURGH, PA/UAS I...
# 1      PRELIM INFO FROM FAA OPS: MIAMI, FL/UAS INCIDE...
# 2      PRELIM INFO FROM FAA OPS: SEATTLE, WA/UAS INCI...
# 3      PRELIM INFO FROM FAA OPS: MOBILE, AL/UAS INCID...
# 4      PRELIM INFO FROM FAA OPS: SEATTLE, WA/UAS INCI...
# ...                                                  ...
# 17889  PRELIM INFO FROM FAA OPS: MIAMI, FL/UAS INCIDE...
# 17890  PRELIM INFO FROM FAA OPS: WEST PALM BEACH, FL/...
# 17891  PRELIM INFO FROM FAA OPS: FORT MYERS, FL/UAS I...
# 17892  PRELIM INFO FROM FAA OPS: HONOLULU, HI/UAS INC...
# 17893  PRELIM INFO FROM FAA OPS: ORLANDO, FL/UAS INCI...
#
#                                        Source File code
# 0      Reported-UAS-Sightings-April-June-2022.xlsx  AGC
# 1      Reported-UAS-Sightings-April-June-2022.xlsx  OPF
# 2      Reported-UAS-Sightings-April-June-2022.xlsx  BFI
# 3      Reported-UAS-Sightings-April-June-2022.xlsx  BFM
# 4      Reported-UAS-Sightings-April-June-2022.xlsx  SEA
# ...                                            ...  ...
# 17889                 FY2020_Q1_UAS_Sightings.xlsx  TMB
# 17890                 FY2020_Q1_UAS_Sightings.xlsx  PBI
# 17891                 FY2020_Q1_UAS_Sightings.xlsx  JVY
# 17892                 FY2020_Q1_UAS_Sightings.xlsx  HNL
# 17893                 FY2020_Q1_UAS_Sightings.xlsx  DEN
#
# [17892 rows x 6 columns]

# %%
drone_df = big_drone_df.copy()

# %%
'''
All regex commands for drone information extraction.
'''

def extract_direction(summary):
    match = re.search(r'WHILE\s([A-Z]+\sBOUND)', summary)
    if match:
        return match.group(1)
    else:
        return np.nan

drone_df['Direction'] = drone_df['Summary'].apply(extract_direction)

pattern_time = r'(?<=\/)([0-9]{4}[A-Z])'
drone_df['Time'] = drone_df['Summary'].str.extract(pattern_time)

pattern_advised = r'(?<=\/)([A-Z ]+)(?= ADVISED)'
drone_df['Authority Advised'] = drone_df['Summary'].str.extract(pattern_advised)

pattern_route = r'(?<=, )([A-Z  ,()]+ - [A-Z  ,()]+)(?=,)'
drone_df['Route'] = drone_df['Summary'].str.extract(pattern_route)

pattern_location = r'(?<= )([0-9]+ [(W|ESE|E|N|NW|SW|S|SE|NE|NNE|NNW|WNW|WSW|NORTHWEST|ENE|SSE|SSW)]+ [A-Z() ]+)(?= AT| FEET|[.])'
drone_df['Location'] = drone_df['Summary'].str.extract(pattern_location)

pattern_altitude = r'(?<= )(AT [0-9,]+ FEET)(?= )'
drone_df['Altitude'] = drone_df['Summary'].str.extract(pattern_altitude)

drone_df
# Out:
#                       Date         State             City  \
# 0                 4/1/2022  PENNSYLVANIA       PITTSBURGH
# 1                 4/1/2022       FLORIDA            MIAMI
# 2                 4/1/2022    WASHINGTON          SEATTLE
# 3                 4/1/2022       ALABAMA           MOBILE
# 4                 4/1/2022    WASHINGTON          SEATTLE
# ...                    ...           ...              ...
# 17889  2019-12-31 00:00:00       FLORIDA            MIAMI
# 17890  2019-12-31 00:00:00       FLORIDA  WEST PALM BEACH
# 17891  2019-12-31 00:00:00       FLORIDA       FORT MYERS
# 17892  2019-12-31 00:00:00        HAWAII         HONOLULU
# 17893  2019-12-31 00:00:00       FLORIDA          ORLANDO
#
#                                                  Summary  \
# 0      PRELIM INFO FROM FAA OPS: PITTSBURGH, PA/UAS I...
# 1      PRELIM INFO FROM FAA OPS: MIAMI, FL/UAS INCIDE...
# 2      PRELIM INFO FROM FAA OPS: SEATTLE, WA/UAS INCI...
# 3      PRELIM INFO FROM FAA OPS: MOBILE, AL/UAS INCID...
# 4      PRELIM INFO FROM FAA OPS: SEATTLE, WA/UAS INCI...
# ...                                                  ...
# 17889  PRELIM INFO FROM FAA OPS: MIAMI, FL/UAS INCIDE...
# 17890  PRELIM INFO FROM FAA OPS: WEST PALM BEACH, FL/...
# 17891  PRELIM INFO FROM FAA OPS: FORT MYERS, FL/UAS I...
# 17892  PRELIM INFO FROM FAA OPS: HONOLULU, HI/UAS INC...
# 17893  PRELIM INFO FROM FAA OPS: ORLANDO, FL/UAS INCI...
#
#                                        Source File code  Direction   Time  \
# 0      Reported-UAS-Sightings-April-June-2022.xlsx  AGC    S BOUND  2358E
# 1      Reported-UAS-Sightings-April-June-2022.xlsx  OPF    W BOUND  1205E
# 2      Reported-UAS-Sightings-April-June-2022.xlsx  BFI  NNE BOUND  1210P
# 3      Reported-UAS-Sightings-April-June-2022.xlsx  BFM   SE BOUND  1859C
# 4      Reported-UAS-Sightings-April-June-2022.xlsx  SEA    W BOUND  1805P
# ...                                            ...  ...        ...    ...
# 17889                 FY2020_Q1_UAS_Sightings.xlsx  TMB    W BOUND  1811E
# 17890                 FY2020_Q1_UAS_Sightings.xlsx  PBI    E BOUND  1800E
# 17891                 FY2020_Q1_UAS_Sightings.xlsx  JVY    S BOUND  1655E
# 17892                 FY2020_Q1_UAS_Sightings.xlsx  HNL        NaN  1512L
# 17893                 FY2020_Q1_UAS_Sightings.xlsx  DEN   NW BOUND  0706E
#
#             Authority Advised                           Route  \
# 0       ALLEGHENY COUNTY ATCT                             NaN
# 1                         NaN                       DAL - OPF
# 2              SEATTLE TRACON                       HDN - BFI
# 3                 MOBILE APCH                       BFM - FMY
# 4              SEATTLE TRACON  KEFLAVIK, ICELAND (BIKF) - SEA
# ...                       ...                             ...
# 17889    MIAMI EXECUTIVE ATCT                             NaN
# 17890       PALM BEACH TRACON                       DFW - PBI
# 17891         FORT MYERS APCH                       JVY - APF
# 17892                     NaN        HNL - LAHAINA, HI (PHJH)
# 17893  CENTRAL FLORIDA TRACON                             NaN
#
#               Location       Altitude
# 0              6 N AGC  AT 1,600 FEET
# 1              5 E OPF  AT 1,500 FEET
# 2       15 WNW SEATTLE  AT 3,000 FEET
# 3      14 N SEMMES VOR  AT 6,000 FEET
# 4             17 N SEA  AT 7,000 FEET
# ...                ...            ...
# 17889        2 WSW TMB  AT 1,000 FEET
# 17890   1 W PALM BEACH    AT 400 FEET
# 17891  8 SE FORT MYERS  AT 7,000 FEET
# 17892              NaN  AT 1,000 FEET
# 17893         15 E ORL  AT 2,000 FEET
#
# [17892 rows x 12 columns]

# %%
'''
Using Beautiful Soup and Google Search with Airnav in order to map the values for which the FAA code could not be found in original dataset.
'''

edge_df = drone_df[drone_df["code"].isna()]
edge_df_location = edge_df[~edge_df["Location"].isna()]

drone_df['latitude'] = None
drone_df['longitude'] = None

# Iterate over rows
for idx, location in edge_df_location.iterrows():
    loc_list = location['Location'].split()[2:]
    full_string = " ".join(loc_list)
    query_plain = " airnav site:airnav.com"
    query = full_string + query_plain

    # Perform Google search 
    search_results = search(query, num_results=1)  
    final_url = next(search_results, None)
    
    if final_url:
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
        }

        response = requests.get(final_url, headers=headers)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            
            faa_code = None
            latitude = None
            longitude = None
            
            table_rows = soup.find_all('tr')  
            for row in table_rows:
                if 'FAA Identifier' in row.text:
                    faa_code = row.find_all('td')[1].text.strip()  
                
                if 'Lat/Long' in row.text:
                    lat_long_text = row.find_all('td')[1].text.strip()
                    lat_long_split = lat_long_text.split("W")
                    
                    if len(lat_long_split) >= 2:
                        latitude = lat_long_split[0] + 'W' 
                        longitude = 'W' + lat_long_split[1]

            if not (latitude and longitude):
                string_soup = str(soup)
                result_re = re.findall(r'(?<=Lat\/Long:\s)([0-9\-\.]+[N|S])\s\/\s([0-9\-\.]+[E|W])', string_soup)
                if result_re:
                    latitude, longitude = result_re[0]

            if faa_code:
                drone_df.at[idx, 'code'] = faa_code
            if latitude and longitude:
                drone_df.at[idx, 'latitude'] = latitude
                drone_df.at[idx, 'longitude'] = longitude
        else:
            print(f"Failed to fetch the page for {location['Location']}, status code: {response.status_code}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[31], line 20
#      18 # Perform Google search
#      19 search_results = search(query, num_results=1)
# ---> 20 final_url = next(search_results, None)
#      22 if final_url:
#      23     headers = {
#      24         "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
#      25     }
#
# File ~/anaconda3/lib/python3.10/site-packages/googlesearch/__init__.py:50, in search(term, num_results, lang, proxy, advanced, sleep_interval, timeout, safe, ssl_verify, region)
#      46 fetched_results = 0  # Keep track of the total fetched results
#      48 while fetched_results < num_results:
#      49     # Send request
# ---> 50     resp = _req(term, num_results - start,
#      51                 lang, start, proxies, timeout, safe, ssl_verify, region)
#      53     # Parse
#      54     soup = BeautifulSoup(resp.text, "html.parser")
#
# File ~/anaconda3/lib/python3.10/site-packages/googlesearch/__init__.py:26, in _req(term, results, lang, start, proxies, timeout, safe, ssl_verify, region)
#       8 def _req(term, results, lang, start, proxies, timeout, safe, ssl_verify, region):
#       9     resp = get(
#      10         url="https://www.google.com/search",
#      11         headers={
#    (...)
#      24         verify=ssl_verify,
#      25     )
# ---> 26     resp.raise_for_status()
#      27     return resp
#
# File ~/anaconda3/lib/python3.10/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3DBRICKYARD%2BVORTAC%2Bairnav%2Bsite%253Aairnav.com%26num%3D3%26hl%3Den%26start%3D0%26safe%3Dactive&hl=en&q=EhAgAQWoRR-bACFXHs4Es3D6GOuLv7cGIjDpFBycjn4YHiieHZd2MYnc6Q15vfbP0O70b1sBLOOuAV7c7G1KFZHW8jEnmiEn73syAXJaAUM

# %%
'''
Merging the results with the initial airport codes dataframe to get latitude and longitude for all rows.
'''

merged_drone_df = pd.merge(drone_df, airport_codes_2[['Loc Id', 'ARP Latitude DD', 'ARP Longitude DD']], 
                           left_on='code', right_on='Loc Id', how='left')

# Step 2: Only update 'latitude' and 'longitude' where they are NaN in drone_df
merged_drone_df['latitude'] = merged_drone_df['latitude'].fillna(merged_drone_df['ARP Latitude DD'])
merged_drone_df['longitude'] = merged_drone_df['longitude'].fillna(merged_drone_df['ARP Longitude DD'])

# Optional: Drop the 'ARP Latitude DD', 'ARP Longitude DD', and 'Loc Id' columns if you don't need them
merged_drone_df.drop(['Loc Id', 'ARP Latitude DD', 'ARP Longitude DD'], axis=1, inplace=True)
merged_drone_df
# Out:
# /var/folders/97/l1_w165s1z38tw82rlydjzp00000gn/T/ipykernel_73715/4054253587.py:9: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_drone_df['latitude'] = merged_drone_df['latitude'].fillna(merged_drone_df['ARP Latitude DD'])
# /var/folders/97/l1_w165s1z38tw82rlydjzp00000gn/T/ipykernel_73715/4054253587.py:10: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   merged_drone_df['longitude'] = merged_drone_df['longitude'].fillna(merged_drone_df['ARP Longitude DD'])
#                       Date         State             City  \
# 0                 4/1/2022  PENNSYLVANIA       PITTSBURGH
# 1                 4/1/2022       FLORIDA            MIAMI
# 2                 4/1/2022    WASHINGTON          SEATTLE
# 3                 4/1/2022       ALABAMA           MOBILE
# 4                 4/1/2022    WASHINGTON          SEATTLE
# ...                    ...           ...              ...
# 17887  2019-12-31 00:00:00       FLORIDA            MIAMI
# 17888  2019-12-31 00:00:00       FLORIDA  WEST PALM BEACH
# 17889  2019-12-31 00:00:00       FLORIDA       FORT MYERS
# 17890  2019-12-31 00:00:00        HAWAII         HONOLULU
# 17891  2019-12-31 00:00:00       FLORIDA          ORLANDO
#
#                                                  Summary  \
# 0      PRELIM INFO FROM FAA OPS: PITTSBURGH, PA/UAS I...
# 1      PRELIM INFO FROM FAA OPS: MIAMI, FL/UAS INCIDE...
# 2      PRELIM INFO FROM FAA OPS: SEATTLE, WA/UAS INCI...
# 3      PRELIM INFO FROM FAA OPS: MOBILE, AL/UAS INCID...
# 4      PRELIM INFO FROM FAA OPS: SEATTLE, WA/UAS INCI...
# ...                                                  ...
# 17887  PRELIM INFO FROM FAA OPS: MIAMI, FL/UAS INCIDE...
# 17888  PRELIM INFO FROM FAA OPS: WEST PALM BEACH, FL/...
# 17889  PRELIM INFO FROM FAA OPS: FORT MYERS, FL/UAS I...
# 17890  PRELIM INFO FROM FAA OPS: HONOLULU, HI/UAS INC...
# 17891  PRELIM INFO FROM FAA OPS: ORLANDO, FL/UAS INCI...
#
#                                        Source File code  Direction   Time  \
# 0      Reported-UAS-Sightings-April-June-2022.xlsx  AGC    S BOUND  2358E
# 1      Reported-UAS-Sightings-April-June-2022.xlsx  OPF    W BOUND  1205E
# 2      Reported-UAS-Sightings-April-June-2022.xlsx  BFI  NNE BOUND  1210P
# 3      Reported-UAS-Sightings-April-June-2022.xlsx  BFM   SE BOUND  1859C
# 4      Reported-UAS-Sightings-April-June-2022.xlsx  SEA    W BOUND  1805P
# ...                                            ...  ...        ...    ...
# 17887                 FY2020_Q1_UAS_Sightings.xlsx  TMB    W BOUND  1811E
# 17888                 FY2020_Q1_UAS_Sightings.xlsx  PBI    E BOUND  1800E
# 17889                 FY2020_Q1_UAS_Sightings.xlsx  JVY    S BOUND  1655E
# 17890                 FY2020_Q1_UAS_Sightings.xlsx  HNL        NaN  1512L
# 17891                 FY2020_Q1_UAS_Sightings.xlsx  DEN   NW BOUND  0706E
#
#             Authority Advised                           Route  \
# 0       ALLEGHENY COUNTY ATCT                             NaN
# 1                         NaN                       DAL - OPF
# 2              SEATTLE TRACON                       HDN - BFI
# 3                 MOBILE APCH                       BFM - FMY
# 4              SEATTLE TRACON  KEFLAVIK, ICELAND (BIKF) - SEA
# ...                       ...                             ...
# 17887    MIAMI EXECUTIVE ATCT                             NaN
# 17888       PALM BEACH TRACON                       DFW - PBI
# 17889         FORT MYERS APCH                       JVY - APF
# 17890                     NaN        HNL - LAHAINA, HI (PHJH)
# 17891  CENTRAL FLORIDA TRACON                             NaN
#
#               Location       Altitude   latitude   longitude
# 0              6 N AGC  AT 1,600 FEET  40.354438  -79.929047
# 1              5 E OPF  AT 1,500 FEET  25.907417  -80.278222
# 2       15 WNW SEATTLE  AT 3,000 FEET  47.529972 -122.301944
# 3      14 N SEMMES VOR  AT 6,000 FEET  30.626781  -88.068091
# 4             17 N SEA  AT 7,000 FEET  47.449889 -122.311778
# ...                ...            ...        ...         ...
# 17887        2 WSW TMB  AT 1,000 FEET  25.647564  -80.433225
# 17888   1 W PALM BEACH    AT 400 FEET  26.683162  -80.095592
# 17889  8 SE FORT MYERS  AT 7,000 FEET  38.366618  -85.738145
# 17890              NaN  AT 1,000 FEET  21.317825 -157.920250
# 17891         15 E ORL  AT 2,000 FEET  39.861667 -104.673167
#
# [17892 rows x 14 columns]

# %%
''' 
EXTRACTING 3D COORDINATE OF DRONE BASED ON ALTITUDE, LONGITUDE, AND LATITUDE
Reference: 
    https://stackoverflow.com/questions/16614057/longitude-latitude-altitude-to-3d-cartesian-coordinate-systems
    for calculation of 3D coordinate
'''

# converting latitude and longitude columns to numeric values (currently an object)
merged_drone_df['latitude'] = pd.to_numeric(merged_drone_df['latitude'])
merged_drone_df['longitude'] = pd.to_numeric(merged_drone_df['longitude'])

# dropping rows with NaN values in latitude, longitude, or altitude
merged_drone_df = merged_drone_df.dropna(subset=['latitude', 'longitude', 'Altitude'])

# adjust altitude column with regex to delete the "AT" and "FEET" and only displays numbers
# convert the feet to meters since axis is in meters
merged_drone_df['altitude_numeric'] = merged_drone_df['Altitude'].str.extract(r'(\d{1,3}(?:,\d{3})*)')
merged_drone_df['altitude_numeric'] = merged_drone_df['altitude_numeric'].str.replace(',', '').astype(float)
merged_drone_df['alt_meters'] = merged_drone_df['altitude_numeric'] * 0.3048

# 3D coordinate extracting:

axis = 6378137
eccentricity = 8.1819190842622e-2
asq = np.power(axis, 2)
esq = np.power(eccentricity, 2)

def convert(df):
    df['lat_radian'] = np.radians(df['latitude'])
    df['long_radian'] = np.radians(df['longitude'])

    df['N'] = axis / np.sqrt(1 - esq * np.power(np.sin(df['lat_radian']), 2))

    df['x'] = (df['N'] + df['alt_meters']) * np.cos(df['lat_radian']) * np.cos(df['long_radian'])
    df['y'] = (df['N'] + df['alt_meters']) * np.cos(df['lat_radian']) * np.sin(df['long_radian'])
    df['z'] = ((1 - esq) * df['N'] + df['alt_meters']) * np.sin(df['lat_radian'])

    df.drop(columns=['lat_radian', 'long_radian', 'N'], inplace=True)

    return df

merged_drone_df2 = convert(merged_drone_df)
merged_drone_df2.head()
