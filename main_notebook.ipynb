# %%
# Necessary impports and pip installs
# !pip3 install googlesearch-python
import pandas as pd
import os
import numpy as np
import re
from googlesearch import search
import requests
from bs4 import BeautifulSoup

# %%
big_df = pd.read_csv("fully_merged_dataset.csv")
big_df
# Out:
#        Unnamed: 0                 Date         State             City  \
# 0               0             4/1/2022  PENNSYLVANIA       PITTSBURGH
# 1               1             4/1/2022       FLORIDA            MIAMI
# 2               2             4/1/2022    WASHINGTON          SEATTLE
# 3               3             4/1/2022       ALABAMA           MOBILE
# 4               4             4/1/2022    WASHINGTON          SEATTLE
# ...           ...                  ...           ...              ...
# 17887       17887  2019-12-31 00:00:00       FLORIDA            MIAMI
# 17888       17888  2019-12-31 00:00:00       FLORIDA  WEST PALM BEACH
# 17889       17889  2019-12-31 00:00:00       FLORIDA       FORT MYERS
# 17890       17890  2019-12-31 00:00:00        HAWAII         HONOLULU
# 17891       17891  2019-12-31 00:00:00       FLORIDA          ORLANDO
#
#                                                  Summary  \
# 0      PRELIM INFO FROM FAA OPS: PITTSBURGH, PA/UAS I...
# ...

# %%
null_counts = big_df.isnull().sum()
null_counts
# Out:
# Unnamed: 0               0
# Date                  1719
# State                 2194
# City                  2182
# Summary                  0
# Source File              0
# code                  1308
# Direction             8618
# Time                  1220
# Authority Advised     4932
# Route                12401
# Location              7209
# Altitude              5215
# latitude              1301
# longitude             1301
# dtype: int64

# %%
big_df[big_df["latitude"].isnull()].to_csv("0225.csv")
